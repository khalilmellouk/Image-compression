# %%
import importlib
import Mirm as rm

# %%
# Chemins des fichiers d'entrée et de sortie
input_image_path = 'eren_rgb.jpg'  # Chemin de l'image d'entrée
input_irm_path = 'file.irm'  # Chemin du fichier IRM d'entrée
output_image_path = 'reconstituted.jpg'  # Chemin de l'image de sortie reconstruite

# %%
head = rm.compression_irm(input_image_path,input_irm_path)
# Out:
# c:\Users\khali\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\khali\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# Image compressée sauvegardée avec succès dans le fichier : file.irm

# %%
rm.decompression_irm(head, input_irm_path, output_image_path)
# Out:
# Image décompressée sauvegardée avec succès dans le fichier : reconstituted.jpg

# %%
rm.plot_images(input_image_path, output_image_path)

# %%
erreur = rm.MSE(input_image_path, output_image_path)
print(f"The mean square error (MSE) is: {erreur}")
# Out:
# The mean square error (MSE) is: 64.5511583011583
